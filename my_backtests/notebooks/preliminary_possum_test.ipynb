# %%
import sys, os
repo_root = os.path.abspath("../../")  # two levels up to the pysystemtrade root
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

# %%
from my_backtests.test_system import futures_system
import sys
from pathlib import Path

# make sure the repo root is importable
repo_root = Path.cwd().resolve().parents[1]  # from my_backtests/notebooks
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from my_backtests.test_system import futures_system

config_path = repo_root / "my_backtests" / "configs" / "preliminary-possum.yaml"
system = futures_system(config_filename=str(config_path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 from pathlib import Path
#       3 config_path = Path("..") / "configs" / "preliminary-possum.yaml"
# ----> 4 system = futures_system(config_filename=str(config_path))
#
# File ~/trades/pysystemtrade/my_backtests/test_system.py:37, in futures_system(sim_data, config_filename, rules)
#      34 if sim_data is arg_not_supplied:
#      35     sim_data = csvFuturesSimData()
# ---> 37 config = Config(config_filename)
#      39 if rules is arg_not_supplied:
#      40     rules = Rules()
#
# File ~/trades/pysystemtrade/sysdata/config/configdata.py:87, in Config.__init__(self, config_object, default_filename, private_filename)
#      84 if config_object is arg_not_supplied:
#      85     config_object = dict()
# ---> 87 self._init_config(config_object)
#
# ...
